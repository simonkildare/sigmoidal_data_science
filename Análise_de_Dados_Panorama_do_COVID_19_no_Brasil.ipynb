# %% [markdown]
# <a href="https://colab.research.google.com/github/simonkildare/sigmoidal_data_science/blob/main/An%C3%A1lise_de_Dados_Panorama_do_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Panorama da COVID-19 no Brasil
#
# A COVID-19 é uma doença infecciosa causada pelo coronavírus SARS-CoV-2 e tem como principais sintomas: febre, cansaço e tosse seca. Outros sintomas menos comuns e que podem afetar alguns pacientes são: perda de paladar ou olfato, congestão nasal, conjuntivite, dor de garganta, dor de cabeça, dores nos músculos ou juntas, diferentes tipos de erupção cutânea, náusea ou vômito, diarreia, calafrios ou tonturas.
#
# <center><img alt="Colaboratory logo" width="50%" src="https://www.paho.org/sites/default/files/styles/max_1500x1500/public/2021-05/covid-19-variants.jpg?itok=szJH1mCw"></center>
#
# Formas de Transmissão:
#
# A transmissão do coronavírus costuma ocorrer pelo ar ou por contato pessoal com secreções contaminadas, como:
#
# * Gotículas de saliva;
# * Espirro;
# * Tosse;
# * Catarro;
# * Contato pessoal próximo, como toque ou aperto de mão;
# * Contato com objetos ou superfícies contaminadas, seguido de contato com a boca, nariz ou olhos.
#
# Período de Incubação:
#
# * O período médio de incubação por coronavírus é de 05 dias, com intervalos que chegam a 12 dias, período em que os primeiros sintomas levam para aparecer desde a infecção.
#
# Transmissibilidade:
#
# * A transmissibilidade dos pacientes infectados por SARSCoV ocorre, em média, 07 dias após o início dos sintomas. No entanto, dados preliminares do coronavírus (SARS-CoV-2) sugerem que a transmissão possa ocorrer mesmo sem o aparecimento de sinais e sintomas.
#
# Para mais informações, acesse [COVID-19](https://coronavirus.es.gov.br/).
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19 no Brasil, irei realizar uma análise sobre os dados públicos da doença.

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados usados foram obtidos a partir do repositório, sobre a COVID-19, do [OWID](https://github.com/owid/covid-19-data/tree/master/public/data) (*Our World in Data*).
#
# <center><img alt="Colaboratory logo" width="50%" src="https://terracoeconomico.com.br/wp-content/uploads/2019/04/OurWorldInData.png"></center>
#
# ***Our World In Data*** é uma publicação digital especializada em expor pesquisas empíricas e dados analíticos sobre mudanças nas condições de qualidade de vida ao redor do mundo. A publicação especializa-se em criar visualizações de dados interativas, principalmente gráficos e mapas, além de análises críticas sobre o que impulsiona o desenvolvimento, os fatores que levam as mudanças observadas e suas consequências no mundo.
#
# O *dataset* utilizado para a análise de dados COVID-19 será um arquivo.csv e inclui todos os dados históricos sobre a pandemia.
#
# Neste *dataset* da COVID-19, serão apresentados dados sobre casos e mortes confirmados, internações e internações em unidades de terapia intensiva (UTI), testes e vacinas, bem como outras variáveis de possível interesse.
#
# Restringir o acesso a dados, é uma das dificuldades de se analisar uma doença nova, devido à existência de conflitos entre os dados dos governos federal, estaduais e os não oficiais. Isso dificulta ou inviabiliza a publicação dos dados em telejornais e veículos impressos. É fundamental conhecer a real extensão dos fatos. Esses dados são decisivos para que as pessoas saibam como agir nesse momento tão difícil. É responsabilidade cotidiana desses meios de transmitir informações confiáveis para a sociedade. Essas informações orientam as pessoas e auxiliam nas políticas públicas.
#
#
# ### Dicionário de Variáveis
#
# `iso_code` - ISO 3166-1 alfa-3 - códigos de países de três letras;
#
# `continent` - Continente da localização geográfica;
#
# `location` - Localização geográfica;
#
# `date` - Data de observação;
#
# `total_cases` - Total de casos confirmados de COVID-19;
#
# `new_cases` - Novos casos confirmados de COVID-19;
#
# `new_cases_smoothed` - Novos casos confirmados de COVID-19 (7 dias suavizados);
#
# `total_deaths` - Total de mortes atribuídas à COVID-19;
#
# `new_deaths` - Novas mortes atribuídas à COVID-19;
#
# `new_deaths_smoothed` - Novas mortes atribuídas à COVID-19 (7 dias suavizados);
#
# `total_cases_per_million` - Total de casos confirmados de COVID-19 por 1.000.000 de pessoas;
#
# `new_cases_per_million` - Novos casos confirmados de COVID-19 por 1.000.000 de pessoas;
#
# `new_cases_smoothed_per_million` - Novos casos confirmados de COVID-19 (7 dias suavizados) por 1.000.000 de pessoas;
#
# `total_deaths_per_million` - Total de mortes atribuídas à COVID-19 por 1.000.000 de pessoas;
#
# `new_deaths_per_million` - Novas mortes atribuídas à COVID-19 por 1.000.000 de pessoas;
#
# `new_deaths_smoothed_per_million` - Novas mortes atribuídas à COVID-19 (7 dias suavizados) por 1.000.000 de pessoas;
#
# `reproduction_rate` - Estimativa em tempo real da taxa de reprodução efetiva (R) da COVID-19;
#
# `icu_patients` - Número de pacientes COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia;
#
# `icu_patients_per_million` - Número de pacientes COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas;
#
# `hosp_patients` - Número de pacientes da COVID-19 no hospital em um determinado dia;
#
# `hosp_patients_per_million` - Número de pacientes COVID-19 no hospital em um determinado dia por 1.000.000 de pessoas;
#
# `weekly_icu_admissions` - Número de pacientes COVID-19 recém admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana;
#
# `weekly_icu_admissions_per_million` - Número de pacientes COVID-19 recém admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana por 1.000.000 de pessoas;
#
# `weekly_hosp_admissions` - Número de pacientes COVID-19 recém admitidos em hospitais em uma determinada semana;
#
# `weekly_hosp_admissions_per_million` - Número de pacientes COVID-19 recém admitidos em hospitais em uma determinada semana por 1.000.000 de pessoas;
#
# `total_tests` - Testes totais para a COVID-19;
#
# `new_tests` - Novos testes para a COVID-19 (apenas calculados para dias consecutivos);
#
# `total_tests_per_thousand` - Testes totais para COVID-19 por 1.000 pessoas;
#
# `new_tests_per_thousand` - New tests for COVID-19 per 1,000 people;
#
# `new_tests_smoothed` - Novos testes para a COVID-19 (7 dias suavizados). Para países que não relatam dados de testes diariamente, assumimos que os testes mudaram igualmente diariamente em quaisquer períodos em que não foram relatados dados. Isto produz uma série completa de números diários, que é então calculada como média em uma janela rolante de 7 dias;
#
# `new_tests_smoothed_per_thousand` - Novos testes para COVID-19 (7 dias suavizados) por 1.000 pessoas;
#
# `positive_rate` - A parte dos testes COVID-19 que são positivos, dada como média móvel de 7 dias (este é o inverso dos tests_per_case);
#
# `tests_per_case` - Testes realizados por novo caso confirmado de COVID-19, dado como uma média móvel de 7 dias (este é o inverso de positive_rate);
#
# `tests_units` - Unidades utilizadas pelo local para relatar seus dados de teste;
#
# `total_vaccinations` - Número total de doses de vacinação COVID-19 administradas;
#
# `people_vaccinated` - Número total de pessoas que receberam pelo menos uma dose de vacina;
#
# `people_fully_vaccinated` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação;
#
# `total_boosters`- Número total de doses de reforço de vacinação COVID-19 administradas (doses administradas além do número prescrito pelo protocolo de vacinação);
#
# `new_vaccinations` - Novas doses de vacinação COVID-19 administradas (apenas calculadas para dias consecutivos);
#
# `new_vaccinations_smoothed` - Novas doses de vacinação COVID-19 administradas (7 dias suavizadas). Para países que não reportam dados de vacinação diariamente, assumimos que a vacinação mudou igualmente diariamente durante quaisquer períodos em que não foram reportados dados. Isto produz uma série completa de números diários, que é então calculada como média em uma janela rolante de 7 dias;
#
# `total_vaccinations_per_hundred` - Número total de doses de vacinação COVID-19 administradas por 100 pessoas na população total;
#
# `people_vaccinated_per_hundred` - Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas na população total;
#
# `people_fully_vaccinated_per_hundred` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação por 100 pessoas na população total;
#
# `total_boosters_per_hundred`- Número total de doses de reforço de vacinação COVID-19 administradas por 100 pessoas na população total;
#
# `new_vaccinations_smoothed_per_million` - Novas doses de vacinação COVID-19 administradas (7 dias suavizadas) por 1.000.000 de pessoas na população total;
#
# `new_people_vaccinated_smoothed`- Número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias);
#
# `new_people_vaccinated_smoothed_per_hundred`- Número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias) por 100 pessoas na população total;
#
# `stringency_index` - Índice de Estringência de Resposta do Governo: medida composta baseada em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, redimensionada para um valor de 0 a 100 (100 = resposta mais estrita);
#
# `population` - Population in 2020;
#
# `population_density` - Número de pessoas dividido por área de terreno, medido em quilômetros quadrados, ano mais recente disponível;
#
# `median_age` - Idade média da população, projeção da ONU para 2020;
#
# `aged_65_older` - Parte da população com 65 anos de idade ou mais, ano mais recente disponível;
#
# `aged_70_older` - Participação da população com 70 anos de idade ou mais em 2015;
#
# `gdp_per_capita` - Produto interno bruto em paridade de poder de compra (dólar internacional constante em 2011), ano mais recente disponível;
#
# `extreme_poverty` - Participação da população vivendo em extrema pobreza, ano mais recente disponível desde 2010;
#
# `cardiovasc_death_rate` - Taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas);
#
# `diabetes_prevalence` - Prevalência do diabetes (% da população de 20 a 79 anos de idade) em 2017;
#
# `female_smokers` - Participação de mulheres que fumam, ano mais recente disponível;
#
# `male_smokers` - Participação de homens que fumam, ano mais recente disponível;
#
# `handwashing_facilities` - Parte da população com instalações básicas de lavagem de mãos nas instalações, o ano mais recente disponível;
#
# `hospital_beds_per_thousand` - Leitos hospitalares por 1.000 pessoas, o ano mais recente disponível desde 2010;
#
# `life_expectancy` - Expectativa de vida ao nascer em 2019;
#
# `human_development_index` - Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano - uma vida longa e saudável, conhecimento e um padrão de vida decente;
#
# `excess_mortality_cumulative_absolute`- Diferença cumulativa entre o número relatado de óbitos desde 1º de janeiro de 2020 e o número projetado de óbitos para o mesmo período com base em anos anteriores;
#
# `excess_mortality_cumulative`-  Diferença percentual entre o número acumulado de mortes desde 1 de janeiro de 2020 e as mortes cumulativas projetadas para o mesmo período com base em anos anteriores;
#
# `excess_mortality`- Diferença percentual entre o número relatado de mortes semanais ou mensais em 2020–2021 e o número projetado de mortes para o mesmo período com base em anos anteriores;
#
# `excess_mortality_cumulative_per_million`- Diferença cumulativa entre o número relatado de mortes desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base em anos anteriores, por milhão de pessoas.
#
#
#
# ### Importando os dados da COVID-19
#
# Neste momento, serão importados os dados e os pacotes necessários para a análise.
#
# * `owid-covid-data.csv` - Dados sobre a COVID-19 (coronavírus) por *Our World in Data*.

# %%
# importar as bibliotecas necessárias

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_style()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')


# importar o dataset COVID-19 para um DataFrame

df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

pd.set_option('display.max_columns', 60)

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Aqui identificamos os comportamentos médios e discrepantes, procurando e identificando tendências, avaliando os comportamentos e investigando a interdependência entre as variáveis.
#
# Vamos utilizar algumas técnicas adequadas para gerar insights obtidos na análise, como: Tabelas de dados, Histogramas, Box Plot (Diagrama de Caixa), Análise de *Outliers* e etc.
#
#
# ### Análise Exploratória Inicial
#
# Parte importante da nossa análise, é descobrir o tamanho do dataset que estamos encarando.
#
# Vamos verificar:

# %%
# verificando as dimensões
print('Dimensões do Dataset',
    '\nVariáveis: ',df.shape[1], "\n"
      'Entradas: ', df.shape[0])

# verificando as primeiras entradas
df.head()
# Out:
# Dimensões do Dataset
# Variáveis:  67
# Entradas:  176224
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# ...

# %% [markdown]
# **Nomes das colunas**
#
# Nesta parte podemos ver o nome de cada uma das 67 variáveis presentes no *DataFrame*, é possível encontrar seu dicionário no inicío do projeto, onde todas estão adequadamente traduzidas.

# %%
# extrair os nomes das colunas
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# Outro detalhe importante é que precisamos verificar e garantir que os tipos de variáveis estão da forma mais adequada para a análise. Para isso, utilizaremos o método `dtypes`.

# %%
# verificando o tipo das variáveis
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# Notamos que a maioria dos dados são do tipo ***Float*** e alguns são do tipo ***Object***.

# %% [markdown]
# Outro detalhe importante é a verificação em relação aos dados ausentes. Lembre-se de se atentar não para **quais** dados estão faltando, mas também o **motivo** deles estarem faltando.
#
# Para isso, é importante verificar a fonte dos dados, entender a coleta deles, verificar a aleatoriedade dessa ausência, etc.

# %%
# verificando dados ausentes
round((df.isnull().sum() / df.shape[0]).sort_values(ascending=False),2)
# Out:
# weekly_icu_admissions_per_million          0.97
# weekly_icu_admissions                      0.97
# excess_mortality_cumulative_per_million    0.97
# excess_mortality                           0.97
# excess_mortality_cumulative                0.97
#                                            ...
# total_cases                                0.04
# population                                 0.01
# date                                       0.00
# location                                   0.00
# iso_code                                   0.00
# Length: 67, dtype: float64

# %%
# as 40 primeiras variáveis
round((df.isnull().sum() / df.shape[0]).sort_values(ascending=False),2)[:40]
# Out:
# weekly_icu_admissions_per_million             0.97
# weekly_icu_admissions                         0.97
# excess_mortality_cumulative_per_million       0.97
# excess_mortality                              0.97
# excess_mortality_cumulative                   0.97
# excess_mortality_cumulative_absolute          0.97
# weekly_hosp_admissions_per_million            0.94
# weekly_hosp_admissions                        0.94
# total_boosters                                0.89
# total_boosters_per_hundred                    0.89
# icu_patients_per_million                      0.87
# icu_patients                                  0.87
# hosp_patients                                 0.86
# hosp_patients_per_million                     0.86
# new_vaccinations                              0.78
# people_fully_vaccinated                       0.76
# people_fully_vaccinated_per_hundred           0.76
# people_vaccinated                             0.74
# ...

# %% [markdown]
# **Tratamento de Dados**
#
# A qualidade de um dataset está diretamente relacionada à quantidade de valores ausentes. É importante entender logo no início se esses valores nulos são significativos comparados ao total de entradas.
#
# Analisando os dados ausentes, é notável que:
#
# * `weekly_icu_admissions_per_million`, `weekly_icu_admissions`,`excess_mortality_cumulative_per_million`, `excess_mortality`, `excess_mortality_cumulative`, `excess_mortality_cumulative_absolute`,`weekly_hosp_admissions_per_million` e `weekly_hosp_admissions`- se tornam variáveis irrelevantes para a análise, uma vez que, cerca de mais de 90% dos valores estão ausentes e por isso podem ser excluídas. A variável `tests_units`, também será excluída pois não há relevância para a análise.
#
# * `icu_patients_per_million`, `icu_patients`, `hosp_patients` e `hosp_patients_per_million` - são variáveis referentes a um único dia de registro, possuem mais de 85% dos valores ausentes. Sendo assim, estes serão excluídos, a fim de termos uma análise o mais próximo possível da realidade.
#
# * `total_boosters`, `total_boosters_per_hundred`, `new_vaccinations` , `people_fully_vaccinated`,`people_fully_vaccinated_per_hundred`,`people_vaccinated`, `people_vaccinated_per_hundred`,`total_vaccinations_per_hundred`, `total_vaccinations`,`new_people_vaccinated_smoothed`, `new_people_vaccinated_smoothed_per_hundred`,
# `new_vaccinations_smoothed_per_million` e `new_vaccinations_smoothed` - são variáveis referentes a vacinação, cujas campanhas começaram recentemente, explicando assim a quantidade de valores ausentes. Para análise, os valores faltantes serão preenchidos com 0.

# %% [markdown]
# **Excluindo Variáveis**
#
# Aqui iremos excluir as variáveis irrelevantes para a análise, citadas acima.

# %%
# Criando cópia do DataFrame
df_clean = df.copy()

# Excluindo as Variáveis
df_clean = df_clean.drop(['weekly_icu_admissions_per_million', 'weekly_icu_admissions', 'excess_mortality_cumulative_per_million', 'excess_mortality', 'excess_mortality_cumulative', 'excess_mortality_cumulative_absolute', 'weekly_hosp_admissions_per_million', 'weekly_hosp_admissions', 'tests_units', 'icu_patients_per_million', 'icu_patients',  'hosp_patients', 'hosp_patients_per_million'], axis=1)

# Checando corpo do DataFrame após a exclusão
print('Número de colunas antes da exclusão {}'. format(df.shape[1]))
print('Número de colunas após a exclusão {}'.format(df_clean.shape[1]))
# Out:
# Número de colunas antes da exclusão 67
# Número de colunas após a exclusão 54

# %% [markdown]
# Podemos ver que o DataFrame teve uma mudança considerável, de 67 colunas foi para 54 colunas, 13 delas possuíam a maioria de seus dados ausentes, isso seria irrelevante para a análise.

# %%
df_clean.isnull().sum()
# Out:
# iso_code                                           0
# continent                                      10333
# location                                           0
# date                                               0
# total_cases                                     6319
# new_cases                                       6544
# new_cases_smoothed                              8539
# total_deaths                                   24396
# new_deaths                                     24397
# new_deaths_smoothed                            26560
# total_cases_per_million                         7106
# new_cases_per_million                           7331
# new_cases_smoothed_per_million                  9320
# total_deaths_per_million                       25170
# new_deaths_per_million                         25171
# new_deaths_smoothed_per_million                27328
# reproduction_rate                              44692
# total_tests                                   102467
# ...

# %% [markdown]
# **Incluindo Valores Faltantes (Vacinação)**
#
# Em seguida, iremos definir uma função para preencher os valores faltantes (Vacinação) com 0, uma vez que as campanhas de vacinação começaram após o início do registro dos dados, onde não houve vacinações e por isso podemos colocar esses valores faltantes como 0.

# %%
# Definindo função para preencher os valores faltantes com 0
def preencher_Vac(x):
  x.fillna(0, inplace=True)
  return

# Criando lista das variáveis a serem preenchidas
Vac_Zero = [df_clean.total_boosters, df_clean.total_boosters_per_hundred, df_clean.new_vaccinations, df_clean.people_fully_vaccinated, df_clean.people_fully_vaccinated_per_hundred, df_clean.people_vaccinated, df_clean.people_vaccinated_per_hundred, df_clean.total_vaccinations_per_hundred, df_clean.total_vaccinations, df_clean.new_people_vaccinated_smoothed, df_clean.new_people_vaccinated_smoothed_per_hundred, df_clean.new_vaccinations_smoothed_per_million, df_clean.new_vaccinations_smoothed, df_clean.gdp_per_capita]

# Loop para executar a função em cada variável da lista
for i in Vac_Zero:
  preencher_Vac(i)

# %% [markdown]
# Aqui, verificamos que as variáveis referentes à vacinação foram preenchidas como o esperado. Sendo assim, não possuem mais valores ausentes.

# %%
# Verificando se os Valores faltantes foram preenchidos
(df_clean.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# new_tests_per_thousand                        0.595441
# new_tests                                     0.595441
# handwashing_facilities                        0.594266
# total_tests_per_thousand                      0.581459
# total_tests                                   0.581459
# tests_per_case                                0.522942
# positive_rate                                 0.518017
# new_tests_smoothed_per_thousand               0.480752
# new_tests_smoothed                            0.480752
# extreme_poverty                               0.461850
# male_smokers                                  0.382445
# female_smokers                                0.373859
# hospital_beds_per_thousand                    0.268930
# reproduction_rate                             0.253609
# stringency_index                              0.218285
# human_development_index                       0.194718
# aged_65_older                                 0.182626
# ...

# %% [markdown]
# **Visualizando Dados**
#
# Como vimos ao analisar o tipo das variáveis, verificamos que a coluna `date` não está em formato datetime. Para que possamos explorar essa variável ao máximo, vamos transformá-la para o formato datetime.

# %%
# transformando a coluna data em datetime
df_clean.date = pd.to_datetime(df_clean.date)

# %% [markdown]
# Após alterar o formato, vamos verificar qual a data mais recente do nosso dataset. Com essa informação, vamos verificar o país líder em casos naquele momento.

# %%
# verificando a data mais recente do dataset
df_clean.date.max()
# Out:
# Timestamp('2022-04-03 00:00:00')

# %% [markdown]
# Para que seja possível retornarmos os valores dos 5 países com mais casos, iremos criar uma lista de **continentes** e outra lista de **rendas** com os valores que nós não queremos que sejam retornados na localização.

# %%
# Criar lista com o nome dos Continentes
continentes = ['Europe', 'Asia', 'North America', 'South America', 'Oceania', 'Africa', 'European Union']

# %%
# Criar lista com o nome das Rendas
rendas = ['High income', 'Upper middle income', 'Lower middle income']

# %% [markdown]
# **Países com mais casos**

# %%
# Localizar quais Países possuem mais casos para data mais atual '2022-03-21'
df_clean.loc[~df_clean.location.isin(continentes)][~df_clean.location.isin(rendas)][df_clean.date == '2022-03-21'].sort_values(by='total_cases', ascending=False)[0:6]
# Out:
#         iso_code      continent        location       date  total_cases  \
# 173994  OWID_WRL            NaN           World 2022-03-21  472119061.0
# 166794       USA  North America   United States 2022-03-21   79784079.0
# 73982        IND           Asia           India 2022-03-21   43010971.0
# 22899        BRA  South America          Brazil 2022-03-21   29650082.0
# 56767        FRA         Europe          France 2022-03-21   24214159.0
# 165991       GBR         Europe  United Kingdom 2022-03-21   20380278.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 173994  1470521.0         1749004.143     6094316.0      4869.0
# 166794    42219.0           31360.429      973126.0      1528.0
# 73982      1581.0            2129.857      516543.0        33.0
# 22899     12268.0           36962.429      657595.0       100.0
# 56767     24231.0           89770.571      141154.0       152.0
# 165991   225992.0           88984.143      163826.0       168.0
#
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://revistaforum.com.br/u/fotografias/m/2020/12/3/f960x540-57291_131366_0.jpg"></center>

# %% [markdown]
# Podemos notar que os Países que mais possuem casos, em ordem, são:
#
# * **Estados Unidos** - 79.780.432 casos registrados, podemos levar em consideração as dimensões do País, **a lentidão da resposta da Casa Branca** - onde precisavam ter tomado medidas mais sérias e abrangentes bem antes, **problemas com testes** - testes defeituosos, que tiveram de ser substituídos e o acesso limitado aos exames, atrasaram a resposta ao avanço da doença e **a falta de coordenação dos Estados**;
#
# * **Índia** - 43.010.971 casos registrados, a **alta população**, cerca de 1.3 bilhões de pessoas e a **elevada densidade** da Índia, com isso, é extremamente difícil fazer o isolamento. Portanto, acarretou em hospitais em colapso, pacientes sem vagas nas UTIs e falta de oxigênio para quem precisa;
#
# * **Brasil** - 29.650.082 casos registrados, um dos países mais populosos do mundo. Alguns aspectos que elevaram a contaminação do vírus foram a **falta da coordenação do ponto de vista de gestão**, **falta de comunicação social**, no sentido de falar com a população e explicar de forma didática formas de prevenção e o incentivo à vacinação, **falta de investimento na atenção básica**, com um importante papel no diagnóstico precoce e testagem, para uma melhor gestão e contenção da pandemia;
#
# * **França** - 24.214.159 casos registrados, um dos fatores para a elevada quantidade de casos foi devido ao **governo que demorou a adotar medidas** para conter a propagação do vírus, como também, a **inconsistência das medidas adotadas** e a **falta de aplicação das recomendações da OMS**;
#
# * **Reino Unido** - 20.380.278 casos registrados, um dos motivos que elevaram os casos, foram as autoridades sanitárias que **retardaram a imposição de medidas rígidas de restrição**, como o ***lockdown***, bloqueando a movimentação de pessoas. Possíveis falhas em **programas de testagem**, rastreamento e isolamento de infectados.

# %% [markdown]
# **Continentes com mais casos**

# %%
df_clean.loc[df_clean.location.isin(continentes)][df_clean.date == '2022-03-21'].sort_values(by='total_cases', ascending=False)
# Out:
#         iso_code continent        location       date  total_cases  new_cases  \
# 52082   OWID_EUR       NaN          Europe 2022-03-21  172436540.0   674160.0
# 9242    OWID_ASI       NaN            Asia 2022-03-21  133659265.0   631527.0
# 52884   OWID_EUN       NaN  European Union 2022-03-21  119785488.0   347981.0
# 117648  OWID_NAM       NaN   North America 2022-03-21   94153735.0    55175.0
# 147543  OWID_SAM       NaN   South America 2022-03-21   55626209.0    27248.0
# 1537    OWID_AFR       NaN          Africa 2022-03-21   11467302.0     7285.0
# 120912  OWID_OCE       NaN         Oceania 2022-03-21    4775289.0    75126.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 52082           759207.857     1755205.0      1471.0             1774.857
# 9242            813507.571     1390788.0      1323.0             1594.143
# 52884           600127.714     1036986.0       848.0             1088.857
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://www.remessaonline.com.br/blog/wp-content/uploads/2020/09/coronav%C3%ADrus-europa-COVID-economia.png"></center>

# %% [markdown]
# Como podemos verificar a tabela acima, segue a ordem dos continentes:
#
# * **Mundo** - 472.114.840 casos registrados em todo o Mundo;
#
# * **Europa** - 172.474.244 casos registrados;
#
# * **Ásia** - 133.622.530 casos registrados;
#
# * **América do Norte** - 94.148.545 casos registrados;
#
# * **América do Sul** - 55.626.209 casos registrados;
#
# * **África** - 11.467.302 casos registrados;
#
# * **Oceania** - 4.775.289 casos registrados;

# %% [markdown]
# **Países com mais mortes**

# %%
# Localizar quais Países possuem mais mortes para data mais atual '2022-03-21'
df_clean.loc[~df_clean.location.isin(continentes)][~df_clean.location.isin(rendas)][df_clean.date == '2022-03-21'].sort_values(by='total_deaths', ascending=False)[0:6]
# Out:
#         iso_code      continent       location       date  total_cases  \
# 173994  OWID_WRL            NaN          World 2022-03-21  472119061.0
# 166794       USA  North America  United States 2022-03-21   79784079.0
# 22899        BRA  South America         Brazil 2022-03-21   29650082.0
# 73982        IND           Asia          India 2022-03-21   43010971.0
# 131948       RUS         Europe         Russia 2022-03-21   17356036.0
# 103666       MEX  North America         Mexico 2022-03-21    5634829.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 173994  1470521.0         1749004.143     6094316.0      4869.0
# 166794    42219.0           31360.429      973126.0      1528.0
# 22899     12268.0           36962.429      657595.0       100.0
# 73982      1581.0            2129.857      516543.0        33.0
# 131948    28342.0           33034.857      357634.0       400.0
# 103666      901.0            3854.857      322092.0        20.0
#
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://static.dw.com/image/59258381_605.jpg"></center>

# %% [markdown]
# Em relação às mortes, os países que lideravam aos 21 de Março de 2022 eram:
#
# * **Estados Unidos** - 972.658;
#
# * **Brasil** - 657.595;
#
# * **Índia** - 516.543;
#
# * **Rússia** - 357.634;
#
# * **México** - 322.092.

# %% [markdown]
# **Continentes com mais mortes**

# %%
df_clean.loc[df_clean.location.isin(continentes)][df_clean.date == '2022-03-21'].sort_values(by='total_deaths', ascending=False)
# Out:
#         iso_code continent        location       date  total_cases  new_cases  \
# 52082   OWID_EUR       NaN          Europe 2022-03-21  172436540.0   674160.0
# 117648  OWID_NAM       NaN   North America 2022-03-21   94153735.0    55175.0
# 9242    OWID_ASI       NaN            Asia 2022-03-21  133659265.0   631527.0
# 147543  OWID_SAM       NaN   South America 2022-03-21   55626209.0    27248.0
# 52884   OWID_EUN       NaN  European Union 2022-03-21  119785488.0   347981.0
# 1537    OWID_AFR       NaN          Africa 2022-03-21   11467302.0     7285.0
# 120912  OWID_OCE       NaN         Oceania 2022-03-21    4775289.0    75126.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 52082           759207.857     1755205.0      1471.0             1774.857
# 117648           45484.000     1405089.0      1619.0             1219.571
# 9242            813507.571     1390788.0      1323.0             1594.143
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://www.marmoremena.com/wp-content/uploads/2020/04/Visualizing-a-post-Covid-World-Marmore-Blog.jpg"></center>

# %% [markdown]
# Como podemos verificar a tabela acima, segue a ordem dos continentes:
#
# * **Mundo** - 6.094.033 mortes registradas em todo o Mundo;
#
# * **Europa** - 1.755.205 mortes registradas;
#
# * **América do Norte** - 1.404.806 mortes registradas;
#
# * **Ásia** - 1.390.788 mortes registradas;
#
# * **América do Sul** - 1.283.407 mortes registradas;
#
# * **África** - 251.291 mortes registradas;
#
# * **Oceania** - 8.521 mortes registradas;

# %% [markdown]
# **Gráfico para os 5 países com mais casos e mortes**
#
# Para melhorar a visualização, vamos plotar um gráfico de barras. Também será colocada uma barra do Mundo para efeitos de comparação em relação ao top 5 de países com mais mortes.

# %%
# Localizando os dados sobre os Países
USA = df_clean.loc[df_clean.iso_code == 'USA']
IND = df_clean.loc[df_clean.iso_code == 'IND']
BRA = df_clean.loc[df_clean.iso_code == 'BRA']
FRA = df_clean.loc[df_clean.iso_code == 'FRA']
RUS = df_clean.loc[df_clean.iso_code == 'RUS']
MEX = df_clean.loc[df_clean.iso_code == 'MEX']
GBR = df_clean.loc[df_clean.iso_code == 'GBR']

# Localizando os dados sobre o Mundo
WRL = df_clean.loc[df_clean.iso_code == 'OWID_WRL']

# Criando DataFrame com os Países selecionados
paises_grafico_casos = USA.append(IND).append(BRA).append(FRA).append(GBR)
paises_grafico_mortes = USA.append(BRA).append(IND).append(RUS).append(MEX)

# Criando DataFrame com os Países selecionados e o Mundo
paisesMundo_grafico_casos = WRL.append(USA).append(IND).append(BRA).append(FRA).append(GBR)
paisesMundo_grafico_mortes = WRL.append(USA).append(BRA).append(IND).append(RUS).append(MEX)

# Localizando Variáveis na data mais recente
total_casos = paises_grafico_casos.loc[paises_grafico_casos.date == '2022-03-21',['date', 'location', 'total_cases']].sort_values(by='total_cases', ascending=False)
total_mortes = paises_grafico_mortes.loc[paises_grafico_mortes.date == '2022-03-21',['date', 'location', 'total_deaths']].sort_values(by='total_deaths', ascending=False)
total_casos_mundo = paisesMundo_grafico_casos.loc[paisesMundo_grafico_casos.date == '2022-03-21',['date', 'location', 'total_cases']].sort_values(by='total_cases', ascending=False)
total_mortes_mundo = paisesMundo_grafico_mortes.loc[paisesMundo_grafico_mortes.date == '2022-03-21',['date', 'location', 'total_deaths']].sort_values(by='total_deaths', ascending=False)


# Plotando os gráficos de barras
fig, ax = plt.subplots(nrows=1 , ncols=4, figsize=(26,8))

# Definindo estilo dos Gráficos para o estilo do Seaborn
sns.set()

# Gráfico 1
sns.barplot(x='location', y=total_casos['total_cases'], data=paises_grafico_casos, ax=ax[0], palette='mako')
ax[0].set_title('Número de Casos Por País')
ax[0].set_ylabel('Total de Casos')
ax[0].set_xlabel('País')

# Gráfico 2
sns.barplot(x='location', y=total_casos_mundo['total_cases'], data=paisesMundo_grafico_casos, ax=ax[1], palette='mako')
ax[1].set_title('Número de Casos por País em Comparação ao Mundo')
ax[1].set_ylabel('Total de Casos')
ax[1].set_xlabel('Localização')

# Gráfico 3
sns.barplot(x='location', y=total_mortes['total_deaths'], data=paises_grafico_mortes, ax=ax[2], palette='mako')
ax[2].set_title('Número de Mortes por País')
ax[2].set_ylabel('Total de Mortes')
ax[2].set_xlabel('País')

# Gráfico 4
sns.barplot(x='location', y=total_mortes_mundo['total_deaths'], data=paisesMundo_grafico_mortes, ax=ax[3], palette='mako')
ax[3].set_title('Número de Mortes por País em Comparação ao Mundo')
ax[3].set_ylabel('Total de Mortes')
ax[3].set_xlabel('Localização')

plt.tight_layout();

# %% [markdown]
# Quando colocamos o Mundo junto dos Países, podemos ver que apesar da quantidade de casos ser grande em um País, a quantidade total de casos no mundo chega a ser de aproximadamente **6% da população mundial**, ou seja, **94% da população mundial** não chegou a contrair a Covid-19. Temos que levar em consideração, que 6% de 7,8 bilhões (de acordo com dados do portal **WorldO’meter**) é uma grande quantidade.
#
# Quando falamos da quantidade total de mortes, temos **6.093.852 mortes no mundo** e **472.114.840 casos**, cerca de **1,3% das pessoas** que contraíram o vírus **morreram**, enquanto **98,7% se recuperaram**.

# %% [markdown]
# ## Gráfico para ver a evolução do total de casos de COVID-19 no mundo
#
# Em seguida, irei plotar um gráfico para que possamos ver a evolução dos casos e mortes de Covid-19 ao decorrer do tempo. Os gráficos terão os Países acima e o Mundo como objeto de análise.

# %%
# Plotando os Gráficos de Linha
fig , ax = plt.subplots(nrows=4, ncols=1, figsize=(20,16))

# Gráfico 1
sns.lineplot(data=df_clean,x=df_clean['date'], y=df_clean['total_cases'] , hue=paises_grafico_casos['location'], palette='tab10' , ax=ax[0])
ax[0].set_title('Número de casos ao decorrer do Tempo')
ax[0].set_xlabel('Data')
ax[0].set_ylabel('Número de Casos')

# Gráfico 2
sns.lineplot(data=df_clean,x=df_clean['date'], y=df_clean['total_cases'], hue=paisesMundo_grafico_casos['location'], palette='tab10', ax=ax[1])
ax[1].set_title('Número de Casos ao decorrer do Tempo em relação ao Mundo')
ax[1].set_xlabel('Data')
ax[1].set_ylabel('Número de Casos')

# Gráfico 3
sns.lineplot(data=df_clean, x=df_clean['date'], y=df_clean['total_deaths'], hue=paises_grafico_mortes['location'], palette='tab10', ax=ax[2])
ax[2].set_title('Número de Mortes ao decorrer do Tempo')
ax[2].set_xlabel('Data')
ax[2].set_ylabel('Número de Mortes')

# Gráfico 4
sns.lineplot(data=df_clean, x=df_clean['date'], y=df_clean['total_deaths'], hue=paisesMundo_grafico_mortes['location'], palette='tab10', ax=ax[3])
ax[3].set_title('Número De Mortes ao decorrer do Tempo em relação ao Mundo')
ax[3].set_xlabel('Data')
ax[3].set_ylabel('Número de mortes')


plt.tight_layout();

# %% [markdown]
# Alguns dos insights que podemos retirar dos gráficos são:
#
# Os Estados Unidos se manteve em primeiro na quantidade de casos, sendo que no final do ano de 2020 houve um aumento expressivo no registro de casos.
#
# A Índia possui uma quantidade de casos superior ao do Brasil, em contrapartida, o Brasil possui maior número de mortes que o país asiático.
#
# Quando colocamos o Mundo no gráfico, o crescimento dele se torna bem mais expressivo, uma vez que é a soma dos casos e mortes, respectivamente, de todos os Países do planeta.

# %% [markdown]
# **Renda Per Capita**
#
# A renda per capita ou rendimento per capita é um indicador que ajuda a medir o grau de desenvolvimento econômico de um país ou região. A renda per capita é obtida mediante a divisão da Renda Nacional (isto é, Produto Nacional Bruto menos os gastos de depreciação do capital e os impostos diretos) pelo número de habitantes do país. Por vezes o Produto Interno Bruto (PIB) é usado.

# %%
df_clean.loc[~df_clean.location.isin(continentes)][~df_clean.location.isin(rendas)][df_clean.date == '2022-03-21'].sort_values(by='gdp_per_capita', ascending=False)[0:10]
# Out:
#        iso_code continent              location       date  total_cases  \
# 130386      QAT      Asia                 Qatar 2022-03-21     360109.0
# 96108       MAC      Asia                 Macao 2022-03-21         82.0
# 95305       LUX    Europe            Luxembourg 2022-03-21     201718.0
# 142822      SGP      Asia             Singapore 2022-03-21    1022555.0
# 24392       BRN      Asia                Brunei 2022-03-21     126109.0
# 77842       IRL    Europe               Ireland 2022-03-21    1390177.0
# 165197      ARE      Asia  United Arab Emirates 2022-03-21     888070.0
# 86206       KWT      Asia                Kuwait 2022-03-21     627584.0
# 120112      NOR    Europe                Norway 2022-03-21    1383227.0
# 153731      CHE    Europe           Switzerland 2022-03-21    3329950.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 130386      153.0             121.429         677.0         0.0
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://www.flaviapiresexplora.com.br/wp-content/uploads/2019/12/dicas_de_doha-ta_por_onde-3-740x525.png"></center>

# %% [markdown]
# **Catar**
#
# O país, que tem apenas 2,3 milhões de habitantes, possui um PIB (PPC) per capita de US$ 116.935. A indústria de exploração de petróleo representa 70% da receita da nação, 60% de seu PIB e 85% dos seus ganhos de exportação. Toda essa riqueza levou a FIFA a escolher o Catar como sede da próxima Copa do Mundo de futebol, em 2022.

# %% [markdown]
# **Gráfico de dispersão considerando gdp_per_capita (ou seja, o PIB dos países) pelo número total de mortos**

# %%
# plotar scatter plot e regressão linear
fig, ax = plt.subplots()
ax.set_xlim(right=60000)
ax.set_ylim(top=700000)
sns.regplot('gdp_per_capita', 'total_deaths', scatter_kws={"s": .5},
            line_kws={"color": "red"}, data=df_clean, ax=ax)

plt.show()

# %% [markdown]
# Neste gráfico de dispersão há uma correlação nula, ou seja, quando há uma grande dispersão entre os pontos ou eles não seguem tendência positiva nem negativa, significa que não há nenhuma correlação aparente entre as variáveis.

# %% [markdown]
# **Participação da população vivendo em extrema pobreza**

# %%
df_clean.loc[~df_clean.location.isin(continentes)][~df_clean.location.isin(rendas)][df_clean.date == '2022-03-21'].sort_values(by='extreme_poverty', ascending=False)[0:6]
# Out:
#        iso_code continent                      location       date  \
# 96853       MDG    Africa                    Madagascar 2022-03-21
# 42156       COD    Africa  Democratic Republic of Congo 2022-03-21
# 26638       BDI    Africa                       Burundi 2022-03-21
# 97589       MWI    Africa                        Malawi 2022-03-21
# 67802       GNB    Africa                 Guinea-Bissau 2022-03-21
# 109406      MOZ    Africa                    Mozambique 2022-03-21
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 96853       63928.0        0.0               8.286        1380.0         0.0
# 42156       86461.0        0.0              16.714        1335.0         0.0
# 26638       38372.0       64.0              14.000          38.0         0.0
# 97589       85563.0        2.0               9.143        2626.0         0.0
# 67802        8113.0        0.0               6.429         169.0         0.0
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://www.news-medical.net/image.axd?picture=2021%2F11%2Fshutterstock_1689848020.jpg"></center>

# %% [markdown]
# A maioria dos países do continente africano possuem um **sistema de saúde enfraquecido** e alta prevalência de **malária, tuberculose e desnutrição**. Isso foi visto como um gatilho para o desastre. Em contrapartida, mesmo com este vasto problema, relativamente obteve um **baixo índice de mortes** por COVID-19. Apesar de terem uma média de idade na faixa dos 20 anos, um clima quente e a infraestrutura limitada de transporte público, fazendo com que dificulte o alastramento da doença, a Índia que também tem uma população jovem e o clima relativamente parecido, é um dos países onde possuem mais mortes por COVID-19.
#
# Alguns pesquisadores desconfiam que várias mortes por COVID-19 na África **não estão sendo contabilizadas**. Alguns fatores como, muita **dificuldade no rastreamento** dos casos, **baixa testagem**, pessoas com **dificuldades de acesso ao hospital**, resultam na morte de pessoas nas suas próprias casas. Muitas mortes não chegam a ser registradas junto às autoridades civis. Pesquisa recente da **ONU na África** descobriu que os sistemas oficiais captam apenas **um em cada três óbitos**.
#
# Para saber mais sobre esse mistério no continente africano, [acesse](https://www1.folha.uol.com.br/equilibrioesaude/2022/03/baixo-indice-de-mortes-por-covid-na-africa-ainda-e-misterio-para-cientistas.shtml).

# %% [markdown]
# **Índice de Desenvolvimento Humano**
#
# Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano - uma vida longa e saudável, conhecimento e um padrão de vida decente.

# %%
df_clean.loc[~df_clean.location.isin(continentes)][~df_clean.location.isin(rendas)][df_clean.date == '2022-03-21'].sort_values(by='human_development_index', ascending=False)[0:6]
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 120112      NOR    Europe       Norway 2022-03-21    1383227.0     3760.0
# 153731      CHE    Europe  Switzerland 2022-03-21    3329950.0    60997.0
# 77842       IRL    Europe      Ireland 2022-03-21    1390177.0    24710.0
# 71659       HKG      Asia    Hong Kong 2022-03-21    1061758.0    14068.0
# 73187       ISL    Europe      Iceland 2022-03-21     173796.0     2990.0
# 60584       DEU    Europe      Germany 2022-03-21   18772331.0    92314.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 120112            3706.714        2169.0         0.0                  NaN
# 153731           26863.714       13445.0        22.0               22.714
# 77842             5206.286        6664.0        26.0                5.714
# 71659            20511.857        6119.0       223.0              262.857
# 73187             1551.143          91.0         0.0                1.429
# ...

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://img.freepik.com/fotos-gratis/modelo-de-coronavirus-covid19-colorido-na-bandeira-nacional-da-noruega-no-conceito-de-mascara-facial-de_489646-10655.jpg"></center>

# %% [markdown]
# O **IDH** é uma medida comparativa usada para classificar os países pelo seu grau de "desenvolvimento humano" e para ajudar a classificar os países como desenvolvidos (desenvolvimento humano muito alto), em desenvolvimento (desenvolvimento humano médio e alto) e subdesenvolvidos (desenvolvimento humano baixo). A estatística é composta a partir de dados de expectativa de vida ao nascer, educação e PIB (PPC) per capita (como um indicador do padrão de vida) recolhidos em nível nacional.
#
# Podemos verificar na tabela acima, que alguns países como, **Noruega, Suiça, Irlanda** e etc, possuem um **alto IDH**. Desse modo, são países **desenvolvidos** e a relação entre o total de mortes e o total de casos, obteve média abaixo de **0,5%** e portanto, foi **muito menor** do que a média do Mundo (**1,3%** das pessoas que contraíram o vírus morreram).
#
# O sucesso desses países se dá ao fato de agirem rapidamente ao menor aumento nas infecções, muito por conta do trabalho das **agências de saúde**. Algumas medidas como: grande número de testagem, isolamento, rastreamento de contato, quarentena, prevenção de eventos supercontagiadores em nível local, o alto investimento do governo em campanha de conscientização da COVID-19 e apoio econômico para ajudarem as pessoas, foram determinantes no combate ao vírus.

# %% [markdown]
# ## Análise Exploratória para o Brasil
#
# Agora para uma análise específica para o Brasil, irei fazer uma cópia do DataFrame que irá me retornar apenas as entradas que possuem o Brasil como localização.
#
# Vamos conhecer esse dataset. Podemos ver as 5 primeiras entradas para isso.

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://img.olhardigital.com.br/wp-content/uploads/2021/07/brasil-covid-1279x450.jpg"></center>

# %%
# Criando cópia do DataFrame para o Brasil
df_brasil = df_clean.loc[df_clean.location == 'Brazil'].copy()

# Checar as 5 primeiras entradas
df_brasil.head()
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 22145      BRA  South America   Brazil 2020-02-26          1.0        1.0
# 22146      BRA  South America   Brazil 2020-02-27          1.0        0.0
# 22147      BRA  South America   Brazil 2020-02-28          1.0        0.0
# 22148      BRA  South America   Brazil 2020-02-29          2.0        1.0
# 22149      BRA  South America   Brazil 2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 22145                 NaN           NaN         NaN                  NaN
# 22146                 NaN           NaN         NaN                  NaN
# 22147                 NaN           NaN         NaN                  NaN
# 22148                 NaN           NaN         NaN                  NaN
# 22149                 NaN           NaN         NaN                  NaN
#
#        total_cases_per_million  new_cases_per_million  \
# ...

# %% [markdown]
# **Data Mais Recente**
#
# Vamos checar a data mais recente do dataset, assim saberemos de quando são os dados.

# %%
# Checar a data da última entrada do DataFrame
df_brasil.date.max()
# Out:
# Timestamp('2022-04-03 00:00:00')

# %% [markdown]
# **Primeira Morte no Brasil**

# %%
# Localizar a data da primeira morte no Brasil
df_brasil.loc[df_brasil['new_deaths'] == 1.0].head(1)
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 22165      BRA  South America   Brazil 2020-03-17        321.0      121.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 22165              41.429           1.0         1.0                  NaN
#
#        total_cases_per_million  new_cases_per_million  \
# 22165                      1.5                  0.565
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# 22165                           0.194                     0.005
#
#        new_deaths_per_million  new_deaths_smoothed_per_million  \
# 22165                   0.005                              NaN
#
#        reproduction_rate  total_tests  new_tests  total_tests_per_thousand  \
# 22165               2.85          NaN        NaN                       NaN
#
#        new_tests_per_thousand  new_tests_smoothed  \
# 22165                     NaN                 NaN
#
# ...

# %% [markdown]
# A primeira morte no Brasil, foi registrada em:
#
# **17 de Março de 2020** - Nesse dia já haviam **321 casos** e foi quando ocorreu a primeira morte por COVID-19 no Brasil.

# %% [markdown]
# **Primeiro Caso no Brasil**

# %%
# Localizar a data do primeiro caso no Brasil
df_brasil.loc[df_brasil['new_cases'] != 0.0].head(1)
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 22145      BRA  South America   Brazil 2020-02-26          1.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 22145                 NaN           NaN         NaN                  NaN
#
#        total_cases_per_million  new_cases_per_million  \
# 22145                    0.005                  0.005
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# 22145                             NaN                       NaN
#
#        new_deaths_per_million  new_deaths_smoothed_per_million  \
# 22145                     NaN                              NaN
#
#        reproduction_rate  total_tests  new_tests  total_tests_per_thousand  \
# 22145                NaN          NaN        NaN                       NaN
#
#        new_tests_per_thousand  new_tests_smoothed  \
# 22145                     NaN                 NaN
#
# ...

# %% [markdown]
# O primeiro caso de COVID-19 no Brasil foi registrado em:
#
# **26 de Fevereiro de 2020** - Data de quando foi registrado o primeiro caso de COVID-19 no Brasil.

# %% [markdown]
# **Tempo decorrido entre o Primeiro Caso e a Primeira Morte**
#
# Uma informação interessante para investigarmos é quanto tempo levou desde o primeiro caso até a primeira morte.

# %%
# importar pacote nescessário para identificar quantos dias se passaram para registrar a primeira morte após o primeiro caso
from datetime import date

# Calculando quantos dias entre o primeiro caso registrado e a primeira morte
dias = df_brasil.date.loc[22165] - df_brasil.date.loc[22145]
print('Foram {} dias entre o primeiro caso e a primeira morte no Brasil.'.format(dias.days))
# Out:
# Foram 20 dias entre o primeiro caso e a primeira morte no Brasil.

# %% [markdown]
# Agora, vamos plotar gráficos de linha em escalas linear e logarítmica para compararmos a evolução dos casos e mortes no Brasil.

# %%
# Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.
x = list(range(768))
z = df_brasil['total_cases']
z2 = df_brasil['total_deaths']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(9, 7))
ax1.set_title('Casos no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Casos')
ax1.plot(x, z)

ax2.set_title('Casos no Brasil (Escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Casos')
ax2.set_yscale('log')
ax2.plot(x, z)

ax3.set_title('Mortes no Brasil')
ax3.set_xlabel('Dias')
ax3.set_ylabel('Mortes')
ax3.plot(x, z2)

ax4.set_title('Mortes no Brasil (Escala logarítmica)')
ax4.set_xlabel('Dias')
ax4.set_ylabel('Mortes')
ax4.set_yscale('log')
ax4.plot(x, z2)
plt.tight_layout()

# %% [markdown]
# ## Conclusão
#
# Levando em consideração o contexto dos dados analisados, vale a pena destacar que:
#
# * Os Estados Unidos é o País com mais casos e mortes por covid, equivalente a 85% e 70%, respectivamente, do continente norte americano.
#
# * O Brasil é o terceiro país com mais casos e o segundo com mais mortes. País que lidera os ambos requisitos na América do Sul, com mais de 50% de representividade em casos e mortes. É o país que mais sofreu com a pandemia no seu continente.
#
# * A Índia foi o oposto do Brasil, sendo o segundo país com mais casos e o terceiro com mais mortes. Representando 32% dos casos e 37% das mortes do continente asiático.
#
# * O México é um caso curioso, pois não se encontra no Top 5 dos maiores casos, mas está no Top 5 de maiores mortes. Na América do Norte, o México representa 6% dos casos e 23% das mortes.
#
# * Na Europa, temos a França como o país com o maior número de casos, aproximadamente 14% em relação ao seu continente. E a Rússia, como o país que tem o maior número de mortes registradas, cerca de 20% das mortes do continente europeu.

# %% [markdown]
# **Número total de doses de vacinação COVID-19**

# %%
df_clean.loc[~df_clean.location.isin(continentes)][~df_clean.location.isin(rendas)][df_clean.date == '2022-03-21'].sort_values(by='total_vaccinations', ascending=False)[0:5]
# Out:
#         iso_code      continent       location       date  total_cases  \
# 173994  OWID_WRL            NaN          World 2022-03-21  472119061.0
# 33564        CHN           Asia          China 2022-03-21     169397.0
# 73982        IND           Asia          India 2022-03-21   43010971.0
# 166794       USA  North America  United States 2022-03-21   79784079.0
# 22899        BRA  South America         Brazil 2022-03-21   29650082.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 173994  1470521.0         1749004.143     6094316.0      4869.0
# 33564      4332.0            4058.000        4638.0         0.0
# 73982      1581.0            2129.857      516543.0        33.0
# 166794    42219.0           31360.429      973126.0      1528.0
# 22899     12268.0           36962.429      657595.0       100.0
#
#         new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# ...

# %%
# instalar o pywaffle
# !pip install pywaffle -q

# %%
# importar as bibliotecas necessárias
from pywaffle import Waffle

# %%
# exemplo de Waffle

fig = plt.figure(
                FigureClass=Waffle,
                rows=10,
                columns=30,
                colors=("#232066", "#983D3D", "#DCB732", "#3a3b35"),
                values={'Brasil': 408,
                        'EUA': 559,
                        'Índia': 1813,
                        'China': 3230}, icons='syringe', icon_size=11,
                legend={'loc': 'upper left', 'bbox_to_anchor': (1.3,1)},
                title={'label': 'Número total de doses de vacinação COVID-19', 'loc': 'left'}
                )
fig.set_tight_layout(False)
plt.show();
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# Conforme a tabela e o gráfico de waffle acima, podemos confirmar que a **China** é o país que mais aplicou doses de vacina da COVID-19. Com um pouco mais de **3 bilhões de doses**. Seguida pela **Índia** com quase **2 bilhões de doses**. Os **EUA** com quase **600 milhões de doses**. E, por fim, o **Brasil** com um pouco mais de **400 milhões de doses**.

# %%
# Plotando os Gráficos de Linha
fig , ax = plt.subplots(nrows=2, ncols=1, figsize=(20,16))

# Gráfico 1
sns.lineplot(data=df_clean,x=df_clean['date'], y=df_clean['new_cases'] , hue=paises_grafico_casos['location'], palette='tab10' , ax=ax[0])
ax[0].set_title('Número de Casos Novos ao decorrer do Tempo')
ax[0].set_xlabel('Data')
ax[0].set_ylabel('Número de Casos Novos')

# Gráfico 2
sns.lineplot(data=df_clean,x=df_clean['date'], y=df_clean['new_cases'], hue=paisesMundo_grafico_casos['location'], palette='tab10', ax=ax[1])
ax[1].set_title('Número de Casos Novos ao decorrer do Tempo em Relação ao Mundo')
ax[1].set_xlabel('Data')
ax[1].set_ylabel('Número de Casos Novos')



plt.tight_layout();

# %%
# Plotando os Gráficos de Linha
fig , ax = plt.subplots(nrows=2, ncols=1, figsize=(20,16))

# Gráfico 1
sns.lineplot(data=df_clean,x=df_clean['date'], y=df_clean['new_deaths'] , hue=paises_grafico_mortes['location'], palette='tab10' , ax=ax[0])
ax[0].set_title('Número de Novas Mortes ao decorrer do Tempo')
ax[0].set_xlabel('Data')
ax[0].set_ylabel('Número de Novas Mortes')

# Gráfico 2
sns.lineplot(data=df_clean,x=df_clean['date'], y=df_clean['new_deaths'], hue=paisesMundo_grafico_mortes['location'], palette='tab10', ax=ax[1])
ax[1].set_title('Número de Novas Mortes ao decorrer do Tempo em Relação ao Mundo')
ax[1].set_xlabel('Data')
ax[1].set_ylabel('Número de Novas Mortes')



plt.tight_layout();

# %% [markdown]
# Para finalizar, podemos verificar nos gráficos acima, que o número de casos novos se estabilizou no segundo semestre de 2021, devido principalmente ao avanço da vacinação. Em contrapartida, no início do ano de 2022 houve um aumento significativo no número de casos no mundo em geral, muito por conta das variantes Delta e *Ômicron*. Com o aumento da vacinação, foi possível visualizar o impacto direto também na diminuição no registro de mortes por COVID-19.
